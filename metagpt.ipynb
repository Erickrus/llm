# %% [markdown]
# <a href="https://colab.research.google.com/github/Erickrus/llm/blob/main/metagpt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# make sure you are not running on EU, it is not allowed
# !curl ipinfo.io
# Out:
# {
#   "ip": "34.19.29.171",
#   "hostname": "171.29.19.34.bc.googleusercontent.com",
#   "city": "The Dalles",
#   "region": "Oregon",
#   "country": "US",
#   "loc": "45.5946,-121.1787",
#   "org": "AS396982 Google LLC",
#   "postal": "97058",
#   "timezone": "America/Los_Angeles",
#   "readme": "https://ipinfo.io/missingauth"
# }

# %%
# !apt upgrade nodejs
# !apt upgrade npm
# !npm --version

# %%
# !npm install -g @mermaid-js/mermaid-cli
# Out:
# npm WARN EBADENGINE Unsupported engine {
# npm WARN EBADENGINE   package: '@mermaid-js/mermaid-cli@10.9.1',
# npm WARN EBADENGINE   required: { node: '^14.13 || >=16.0' },
# npm WARN EBADENGINE   current: { node: 'v12.22.9', npm: '8.5.1' }
# npm WARN EBADENGINE }
# npm WARN EBADENGINE Unsupported engine {
# npm WARN EBADENGINE   package: 'commander@10.0.1',
# npm WARN EBADENGINE   required: { node: '>=14' },
# npm WARN EBADENGINE   current: { node: 'v12.22.9', npm: '8.5.1' }
# npm WARN EBADENGINE }
# npm WARN EBADENGINE Unsupported engine {
# npm WARN EBADENGINE   package: '@puppeteer/browsers@0.5.0',
# npm WARN EBADENGINE   required: { node: '>=14.1.0' },
# npm WARN EBADENGINE   current: { node: 'v12.22.9', npm: '8.5.1' }
# npm WARN EBADENGINE }
# npm WARN EBADENGINE Unsupported engine {
# npm WARN EBADENGINE   package: 'cosmiconfig@8.1.3',
# npm WARN EBADENGINE   required: { node: '>=14' },
# npm WARN EBADENGINE   current: { node: 'v12.22.9', npm: '8.5.1' }
# npm WARN EBADENGINE }
# ...

# %%
# !git clone https://github.com/geekan/metagpt
# Out:
# Cloning into 'metagpt'...
# remote: Enumerating objects: 33091, done.
# remote: Counting objects: 100% (447/447), done.
# remote: Compressing objects: 100% (212/212), done.
# remote: Total 33091 (delta 276), reused 352 (delta 235), pack-reused 32644
# Receiving objects: 100% (33091/33091), 93.02 MiB | 32.03 MiB/s, done.
# Resolving deltas: 100% (24729/24729), done.

# %%
# %cd /content/metagpt
# !pip3 install -q -r requirements.txt
# !python3 setup.py install
# Out:
# /content/metagpt
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 5.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 38.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.7/87.7 kB 9.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.9/45.9 kB 5.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.4/81.4 kB 9.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.5/325.5 kB 28.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 40.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 56.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 47.7 MB/s eta 0:00:00
# ...

# %%
# !python3 setup.py install

# %%
#@title generate config2.yaml
#@markdown please input your API KEY
from getpass import getpass
GOOGLE_API_KEY = getpass("input GOOGLE Gemini API: ")
with open("/content/metagpt/config/config2.yaml", "w") as f:
    f.write(f"""llm:
  api_type: "gemini"
  model: "gemini-pro"
  api_key: "{GOOGLE_API_KEY}"
""")
# Out:
# input GOOGLE Gemini API: ··········

# %%
PROMPT="Write a cli snake game based on pygame"
# !metagpt "{PROMPT}" # --code_review True
# Out:
# 2024-06-18 05:13:47.282 | INFO     | metagpt.const:get_metagpt_package_root:29 - Package root set to /content/metagpt
# 2024-06-18 05:13:56.587 | INFO     | metagpt.team:invest:93 - Investment: $3.0.
# 2024-06-18 05:13:56.589 | INFO     | metagpt.roles.role:_act:402 - Alice(Product Manager): to do PrepareDocuments(PrepareDocuments)
# 2024-06-18 05:13:56.646 | INFO     | metagpt.utils.file_repository:save:57 - save to: /content/metagpt/workspace/20240618051356/docs/requirement.txt
# 2024-06-18 05:13:56.647 | INFO     | metagpt.roles.role:_act:402 - Alice(Product Manager): to do WritePRD(WritePRD)
# 2024-06-18 05:13:56.651 | INFO     | metagpt.actions.write_prd:run:86 - New requirement detected: Write a cli snake game based on pygame
# [CONTENT]
# {
#     "Language": "en_us",
#     "Programming Language": "Python",
#     "Original Requirements": "Write a cli snake game based on pygame",
#     "Project Name": "snake_game",
#     "Product Goals": [
# ...

# %%
# !cat /content/metagpt/workspace/snake_game/snake_game/*
# Out:
# import pygame
# from typing import List
#
# class Snake:
#     def __init__(self, screen_width: int, screen_height: int):
#         self.body: List[pygame.Rect] = [pygame.Rect(screen_width // 2, screen_height // 2, 10, 10)]
#         self.direction: pygame.Vector2 = pygame.Vector2(1, 0)
#
#     def move(self):
#         head = self.body[0]
#         new_head = pygame.Rect(head.x + self.direction.x * 10, head.y + self.direction.y * 10, head.width, head.height)
#
#         self.body.insert(0, new_head)
#         self.body.pop()
#
#     def grow(self):
#         tail = self.body[-1]
#         new_tail = pygame.Rect(tail.x, tail.y, tail.width, tail.height)
#
#         self.body.append(new_tail)
#
#     def check_collision(self, rect: pygame.Rect) -> bool:
#         return rect.colliderect(self.body[0])
#
#
# class Food:
#     def __init__(self, screen_width: int, screen_height: int):
#         self.rect: pygame.Rect = pygame.Rect(0, 0, 10, 10)
# ...
